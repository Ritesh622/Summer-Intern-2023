# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # no quantization

# %%
loss = np.array([(1, 5.028907418251038), (2, 2.9298282265663147), (3, 2.4637275338172913), 
                 (4, 1.7947030067443848), (5, 1.8365589082241058), (6, 1.6894086301326752), (7, 1.6339855194091797), 
                 (8, 1.4499991536140442), (9, 1.5445530414581299), (10, 1.3784281611442566), (11, 1.5330150723457336), 
                 (12, 1.7832671701908112), (13, 1.437162607908249), (14, 1.4137477427721024), (15, 1.715567171573639), 
                 (16, 1.4019025266170502), (17, 1.4699466973543167), (18, 1.7114051282405853), 
                 (19, 1.2608203738927841), (20, 1.2757967710494995)])
acc = np.array([(1, 0.9555), (2, 0.97075), (3, 0.97425), (4, 0.983), (5, 0.98225), (6, 0.98475), (7, 0.98625), 
                (8, 0.9845), (9, 0.9865), (10, 0.98675), (11, 0.98525), (12, 0.98625), (13, 0.98675), (14, 0.986), 
                (15, 0.9845), (16, 0.98775), (17, 0.9865), (18, 0.987), (19, 0.9875), (20, 0.98875)])

# %% [markdown]
# # K level Quantization

# %%
loss_k = np.array([(1, 107.47494697570801), (2, 140.22843170166016), (3, 154.3506317138672), 
        (4, 138.80801010131836), (5, 282.6864318847656), (6, 184.59772109985352), (7, 131.2238597869873), 
        (8, 385.6018524169922), (9, 336.8506088256836), (10, 116.99846839904785), (11, 150.0576400756836), 
        (12, 173.46311569213867), (13, 231.05928802490234), (14, 157.29408645629883), (15, 313.3719253540039), 
        (16, 161.7459487915039), (17, 289.3840866088867), (18, 204.5039520263672), 
        (19, 279.93187713623047), (20, 248.36022567749023)])
acc_k = np.array([(1, 0.088), (2, 0.09375), (3, 0.074), (4, 0.136), (5, 0.0665), 
                  (6, 0.11075), (7, 0.16), (8, 0.09475), (9, 0.061), (10, 0.10425), (11, 0.12575), 
                  (12, 0.10125), (13, 0.141), (14, 0.09975), (15, 0.0665), (16, 0.16425),
                  (17, 0.141), (18, 0.07675), (19, 0.114), (20, 0.10275)])

# %% [markdown]
# # Binary Quantization

# %%
loss_bin = np.array([(1, 23.001418113708496), (2, 25.522605895996094), (3, 62.847225189208984), 
                     (4, 46.34381675720215), (5, 107.57168388366699), (6, 80.52941131591797), 
                     (7, 109.42504692077637), (8, 103.17953681945801), (9, 168.5811424255371), 
                     (10, 142.57934951782227), (11, 154.72422409057617), (12, 206.5232696533203), 
                     (13, 258.8800964355469), (14, 292.6107635498047), (15, 311.27249908447266), 
                     (16, 283.73262786865234),(17, 291.20616912841797), (18, 277.65901947021484), 
                     (19, 397.3150939941406), (20, 545.9339294433594)])
acc_bin = np.array([(1, 0.7985), (2, 0.73625), (3, 0.387), (4, 0.557), (5, 0.31525), (6, 0.36775), 
                    (7, 0.32025), (8, 0.34375), (9, 0.23025), (10, 0.301), (11, 0.288), (12, 0.22825), 
                    (13, 0.2245), (14, 0.222), (15, 0.209), (16, 0.20975), (17, 0.237), (18, 0.257), 
                    (19, 0.18675), (20, 0.15975)])

# %% [markdown]
# # new method

# %%
loss_new_bin = np.array([(1, 56.576894760131836), (2, 62.70163059234619), (3, 65.5023365020752), 
                     (4, 66.86620903015137), (5, 70.34205436706543), (6, 74.62992286682129), 
                     (7, 71.36091423034668), (8, 76.39539337158203), (9, 67.49426651000977), 
                     (10, 70.05851554870605), (11, 74.78802490234375), (12, 73.94586944580078), 
                     (13, 71.08510208129883), (14, 72.91374969482422), (15, 73.77533149719238), 
                     (16, 74.2713737487793), (17, 68.83801078796387), (18, 69.78544998168945), 
                     (19, 70.45505142211914), (20, 77.12801933288574)])
acc_new_bin = np.array([(1, 0.541), (2, 0.367), (3, 0.2935), (4, 0.263), (5, 0.17625), (6, 0.1805), 
                    (7, 0.22), (8, 0.1915), (9, 0.27125), (10, 0.217), (11, 0.2255), (12, 0.22625), 
                    (13, 0.19925), (14, 0.2065), (15, 0.207), (16, 0.22725), (17, 0.2595), (18, 0.26), 
                    (19, 0.23025), (20, 0.22225)])

# %% [markdown]
# # new k level

# %%
loss_new_k = np.array([(1, 101.14050483703613), (2, 245.6662483215332), (3, 145.01922988891602), 
                       (4, 153.33214569091797), (5, 216.0637092590332), (6, 181.52005767822266), 
                       (7, 127.24849891662598), (8, 164.8632698059082), (9, 168.45250701904297), 
                       (10, 264.24369049072266), (11, 287.4124450683594), (12, 303.3507537841797), 
                       (13, 302.77742767333984), (14, 209.91887664794922), (15, 260.5594825744629), 
                       (16, 200.49589920043945), (17, 178.0106315612793), (18, 287.2057800292969), 
                       (19, 235.19476318359375), (20, 202.80339813232422)])
acc_new_k = np.array([(1, 0.08675), (2, 0.09425), (3, 0.123), (4, 0.1095), (5, 0.1315), (6, 0.0845), 
                      (7, 0.09425), (8, 0.15725), (9, 0.14025), (10, 0.08675), (11, 0.08), (12, 0.0825),
                      (13, 0.10825), (14, 0.1025), (15, 0.09175), (16, 0.0775), (17, 0.09275), (18, 0.11725), 
                      (19, 0.104), (20, 0.099)])

# %% [markdown]
# # loss plot

# %%
plt.plot(loss[:, 0], np.log(loss[:, 1]), label='no quant')
plt.plot(loss_bin[:, 0], np.log(loss_bin[:, 1]), label='bin')
plt.plot(loss_k[:, 0], np.log(loss_k[:, 1]), label='k level')
plt.plot(loss_new_bin[:, 0], np.log(loss_new_bin[:, 1]), label='new bin')
plt.plot(loss_new_k[:, 0], np.log(loss_new_k[:, 1]), label='new k')
# plt.plot(loss_rot[:, 1], label='rot')
plt.xlabel("rounds")
plt.ylabel("log loss")
plt.xticks(range(1, 21))
plt.title("log loss vs rounds on MNIST")
plt.legend()
plt.savefig("loss plot.png")
plt.show()

# %% [markdown]
# # Acc plot

# %%
plt.plot(acc[:, 1], label='no quant')
plt.plot(acc_bin[:, 1], label='bin')
plt.plot(acc_k[:, 1], label='k level')
plt.plot(acc_new_bin[:, 0], acc_new_bin[:, 1], label='new bin')
plt.plot(acc_new_k[:, 0], (acc_new_k[:, 1]), label='new k')
# plt.plot(acc_rot[:, 1], label='rot')
plt.xlabel("rounds")
plt.ylabel("accuracy")
plt.xticks(range(20))
plt.title("acc vs rounds on MNIST")
plt.legend()
plt.savefig("acc plot.png")
plt.show()
