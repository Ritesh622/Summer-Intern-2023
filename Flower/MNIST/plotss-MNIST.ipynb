# %%
plt.plot(2**np.arange(1, 7), (avg_loss_k), '--', 
         label='Stochastic k level quantization')
plt.plot(2**np.arange(1, 7), (avg_loss_r), "-",
         label="Stochastic rotation quantization (k level)")
plt.xlabel("K")
plt.ylabel("Cross-entropy loss")
plt.title("Loss vs k on MNIST using LeNet-5 (20 rounds)")
plt.legend()
plt.show()

# %%
plt.plot(loss2[:,0], np.log(loss2[:,1]), label="k=2")
plt.plot(loss4[:,0], np.log(loss4[:, 1]), label="k=4")
plt.plot(loss8[:,0], np.log(loss8[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic k-level quantization")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16[:,0], np.log(loss16[:,1]), label="k=16")
plt.plot(loss32[:,0], np.log(loss32[:, 1]), label="k=32")
plt.plot(loss64[:,0], np.log(loss64[:, 1]), label="k=64")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic k-level quantization")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss2r[:,0], np.log(loss2r[:,1]), label="k=2")
plt.plot(loss4r[:,0], np.log(loss4r[:, 1]), label="k=4")
plt.plot(loss8r[:,0], np.log(loss8r[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16r[:,0], np.log(loss16r[:,1]), label="k=16")
plt.plot(loss32r[:,0], np.log(loss32r[:, 1]), label="k=32")
plt.plot(loss64r[:,0], np.log(loss64r[:, 1]), label="k=64")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %% [markdown]
# # Stochastic K level Quantization (biased)

# %%
loss2_kb = np.array([(1, 73.25416564941406), (2, 72.99502754211426), (3, 78.21234893798828), (4, 72.81840133666992), (5, 75.80401611328125), (6, 86.94787406921387), (7, 86.51589393615723), (8, 88.80240249633789), (9, 97.77874565124512), (10, 106.94441986083984), (11, 121.30336570739746), (12, 131.68651962280273), (13, 141.55840682983398), (14, 146.8982048034668), (15, 150.36772537231445), (16, 140.75636291503906), (17, 145.13943481445312), (18, 138.06499862670898), (19, 144.77428436279297), (20, 148.89335250854492)])
loss4_kb = np.array([(1, 68.60807228088379), (2, 37.44642639160156), (3, 27.220396041870117), (4, 23.74567461013794), (5, 34.72419548034668), (6, 31.792250633239746), (7, 32.238059520721436), (8, 39.28692054748535), (9, 42.94543933868408), (10, 46.186180114746094), (11, 48.3884162902832), (12, 45.82097148895264), (13, 47.98445129394531), (14, 54.527488708496094), (15, 67.39718818664551), (16, 47.466983795166016), (17, 45.169663429260254), (18, 46.336368560791016), (19, 43.597476959228516), (20, 45.436410903930664)])
loss8_kb = np.array([(1, 54.195091247558594), (2, 25.213257789611816), (3, 17.861477375030518), (4, 14.52928876876831), (5, 13.558950185775757), (6, 11.967721700668335), (7, 11.64307188987732), (8, 11.44322681427002), (9, 10.841080665588379), (10, 11.290233850479126), (11, 11.313979148864746), (12, 10.723209619522095), (13, 11.224422693252563), (14, 10.893269062042236), (15, 10.937314987182617), (16, 10.746816396713257), (17, 11.444485187530518), (18, 12.13113522529602), (19, 12.229472637176514), (20, 13.584522724151611)])
loss16_kb = np.array([(1, 47.62699222564697), (2, 22.26039409637451), (3, 15.407835483551025), (4, 12.198782682418823), (5, 10.521316051483154), (6, 9.22366738319397), (7, 8.460659980773926), (8, 7.770050525665283), (9, 7.574484586715698), (10, 7.149228453636169), (11, 6.42425012588501), (12, 6.087917327880859), (13, 6.150566577911377), (14, 5.751606464385986), (15, 5.53492283821106), (16, 5.568516731262207), (17, 5.563351273536682), (18, 5.125014781951904), (19, 5.407025456428528), (20, 5.280023455619812)])
loss32_kb = np.array([(1, 52.85179424285889), (2, 23.285024166107178), (3, 15.191699743270874), (4, 11.271671295166016), (5, 9.49512004852295), (6, 8.432363510131836), (7, 7.362685799598694), (8, 6.437039852142334), (9, 6.093962669372559), (10, 5.350706577301025), (11, 5.2486125230789185), (12, 4.6518460512161255), (13, 4.467970967292786), (14, 4.094709038734436), (15, 3.7965003848075867), (16, 3.612107515335083), (17, 3.5440677404403687), (18, 3.616959273815155), (19, 3.42243754863739), (20, 2.956138849258423)])
loss64_kb = np.array([(1, 53.783127784729004), (2, 23.442809104919434), (3, 15.08024287223816), (4, 11.579766273498535), (5, 9.478907346725464), (6, 7.9426352977752686), (7, 6.948229074478149), (8, 6.173317909240723), (9, 6.050622224807739), (10, 5.357000946998596), (11, 4.474257469177246), (12, 4.3769553899765015), (13, 4.244512438774109), (14, 3.65235698223114), (15, 3.737562596797943), (16, 3.217654526233673), (17, 3.25990229845047), (18, 3.2734798789024353), (19, 2.774634838104248), (20, 2.637295663356781)])

# %%
plt.plot(loss2_kb[:,0], np.log(loss2_kb[:,1]), label="k=2")
plt.plot(loss4_kb[:,0], np.log(loss4_kb[:, 1]), label="k=4")
plt.plot(loss8_kb[:,0], np.log(loss8_kb[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic k-level quantization (biased)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16_kb[:,0], np.log(loss16_kb[:,1]), label="k=16")
plt.plot(loss32_kb[:,0], np.log(loss32_kb[:, 1]), label="k=32")
plt.plot(loss64_kb[:,0], np.log(loss64_kb[:, 1]), label="k=64")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic k-level quantization (biased)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %% [markdown]
# # Stochastic Rotation Quantization (biased)

# %%
loss2_rb = np.array([(1, 47.43067932128906), (2, 22.354413509368896), (3, 15.193897485733032), (4, 11.177151679992676), (5, 9.114100456237793), (6, 8.322268724441528), (7, 7.361976742744446), (8, 6.200644493103027), (9, 5.868602156639099), (10, 5.022901892662048), (11, 4.621611475944519), (12, 4.361302137374878), (13, 4.173585951328278), (14, 3.7827237248420715), (15, 3.7655903697013855), (16, 2.9530163407325745), (17, 3.371244490146637), (18, 3.0344669222831726), (19, 2.9403278827667236), (20, 2.586153030395508)])
loss4_rb = np.array([(1, 59.44050693511963), (2, 25.28099536895752), (3, 15.653668642044067), (4, 11.812070369720459), (5, 9.514711856842041), (6, 8.20366656780243), (7, 7.528479814529419), (8, 6.368427157402039), (9, 5.511960387229919), (10, 5.4442362785339355), (11, 5.145247578620911), (12, 4.869946122169495), (13, 4.650354027748108), (14, 3.9036698937416077), (15, 3.841540575027466), (16, 3.705209970474243), (17, 3.4991469383239746), (18, 3.4041783809661865), (19, 3.399678885936737), (20, 2.9985995292663574)])
loss8_rb = np.array([(1, 61.90494155883789), (2, 27.54563856124878), (3, 16.84420347213745), (4, 12.101487159729004), (5, 9.860107421875), (6, 8.414929389953613), (7, 7.723153591156006), (8, 6.536944031715393), (9, 6.3107651472091675), (10, 5.357868432998657), (11, 4.776718258857727), (12, 4.49920380115509), (13, 4.834811091423035), (14, 4.164524495601654), (15, 4.102549731731415), (16, 3.4137978553771973), (17, 3.443676710128784), (18, 3.1556674242019653), (19, 3.1836518049240112), (20, 2.9038095474243164)])
loss16_rb = np.array([(1, 55.556427001953125), (2, 26.06742238998413), (3, 16.020606756210327), (4, 11.998326778411865), (5, 9.354525804519653), (6, 7.967000961303711), (7, 7.173525452613831), (8, 6.368525147438049), (9, 5.717678904533386), (10, 5.337790608406067), (11, 4.783430814743042), (12, 4.568751096725464), (13, 4.046414136886597), (14, 3.815374732017517), (15, 3.691623330116272), (16, 3.490408718585968), (17, 3.3060413599014282), (18, 3.2598170042037964), (19, 3.140303373336792), (20, 3.0054518580436707)])
loss32_rb = np.array([(1, 59.6455717086792), (2, 25.965543270111084), (3, 15.719865560531616), (4, 11.603551626205444), (5, 9.677833080291748), (6, 7.935888051986694), (7, 6.757715106010437), (8, 6.75931453704834), (9, 5.515777349472046), (10, 5.196690082550049), (11, 4.667233228683472), (12, 4.461089134216309), (13, 4.3389891386032104), (14, 3.9869067072868347), (15, 3.69187468290329), (16, 3.5322880148887634), (17, 3.634052038192749), (18, 3.2155420184135437), (19, 3.2609346508979797), (20, 3.167046308517456)])
loss64_rb = np.array([(1, 51.412333488464355), (2, 22.10402488708496), (3, 13.744120359420776), (4, 9.938399314880371), (5, 8.369431018829346), (6, 7.632418870925903), (7, 6.5118080377578735), (8, 5.9522705078125), (9, 5.458514928817749), (10, 5.200642108917236), (11, 4.524359345436096), (12, 4.332385778427124), (13, 3.960817337036133), (14, 3.8143423199653625), (15, 3.748602271080017), (16, 3.6366317868232727), (17, 3.058907151222229), (18, 3.1650455594062805), (19, 3.2058008313179016), (20, 2.695371985435486)])

# %%
plt.plot(loss2_rb[:,0], np.log(loss2_rb[:,1]), label="k=2")
plt.plot(loss4_rb[:,0], np.log(loss4_rb[:, 1]), label="k=4")
plt.plot(loss8_rb[:,0], np.log(loss8_rb[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization (biased)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16_rb[:,0], np.log(loss16_rb[:,1]), label="k=16")
plt.plot(loss32_rb[:,0], np.log(loss32_rb[:, 1]), label="k=32")
plt.plot(loss64_rb[:,0], np.log(loss64_rb[:, 1]), label="k=64")
# %%
plt.plot(loss2_hf[:,0], np.log(loss2_hf[:,1]), label="k=2")
plt.plot(loss4_hf[:,0], np.log(loss4_hf[:, 1]), label="k=4")
plt.plot(loss8_hf[:,0], np.log(loss8_hf[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization (half of the diagonal fixed to 1)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16_hf[:,0], np.log(loss16_hf[:,1]), label="k=16")
plt.plot(loss32_hf[:,0], np.log(loss32_hf[:, 1]), label="k=32")
plt.plot(loss64_hf[:,0], np.log(loss64_hf[:, 1]), label="k=64")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization (half of the diagonal fixed to 1)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %% [markdown]
# # Stochastic Rotation Quantization (biased, half diagonal fixed to 1)

# %%
loss2_hfb = np.array([(1, 54.512288093566895), (2, 24.103670597076416), (3, 15.40100884437561), (4, 11.639698266983032), (5, 9.232468605041504), (6, 8.046636939048767), (7, 7.069835305213928), (8, 6.4468865394592285), (9, 5.508782744407654), (10, 5.257963299751282), (11, 5.1802555322647095), (12, 4.133564531803131), (13, 4.122977256774902), (14, 3.8585734367370605), (15, 4.135055363178253), (16, 3.401801824569702), (17, 3.352505326271057), (18, 3.426593005657196), (19, 3.5361462831497192), (20, 2.9839985966682434)])
loss4_hfb = np.array([(1, 55.334675788879395), (2, 25.111450672149658), (3, 15.731302261352539), (4, 12.122899532318115), (5, 9.827393054962158), (6, 7.918495416641235), (7, 7.3015135526657104), (8, 6.534044504165649), (9, 5.987295866012573), (10, 5.56529974937439), (11, 4.852272152900696), (12, 4.699738264083862), (13, 4.328287363052368), (14, 4.180119633674622), (15, 3.9238392114639282), (16, 3.66628497838974), (17, 3.563914716243744), (18, 3.436505079269409), (19, 3.2296765446662903), (20, 3.160346269607544)])
loss8_hfb = np.array([(1, 66.69351768493652), (2, 31.47721529006958), (3, 17.65738821029663), (4, 12.49470043182373), (5, 10.05627155303955), (6, 8.210447549819946), (7, 7.14544677734375), (8, 6.4730647802352905), (9, 5.577021837234497), (10, 5.148522138595581), (11, 5.003287672996521), (12, 4.618037462234497), (13, 4.09550666809082), (14, 4.045370280742645), (15, 3.6870996356010437), (16, 3.4733548760414124), (17, 3.3286450505256653), (18, 3.50608891248703), (19, 3.0689945816993713), (20, 3.0506480932235718)])
loss16_hfb = np.array([(1, 55.68750190734863), (2, 26.782588481903076), (3, 16.390724658966064), (4, 12.143066167831421), (5, 9.801040410995483), (6, 8.364648818969727), (7, 7.439044237136841), (8, 6.681395649909973), (9, 5.81095814704895), (10, 5.5686705112457275), (11, 4.848221182823181), (12, 4.533157110214233), (13, 4.490736126899719), (14, 4.265154004096985), (15, 3.809815526008606), (16, 3.4730895161628723), (17, 3.586578130722046), (18, 3.2528205513954163), (19, 3.0119824409484863), (20, 3.127395808696747)])
loss32_hfb = np.array([(1, 49.35168170928955), (2, 22.3392014503479), (3, 14.55692744255066), (4, 11.815402507781982), (5, 9.665432453155518), (6, 8.122286438941956), (7, 6.937105774879456), (8, 6.1952433586120605), (9, 6.245351076126099), (10, 5.301417946815491), (11, 4.68172013759613), (12, 4.279967784881592), (13, 3.841674029827118), (14, 3.8760376572608948), (15, 3.766015112400055), (16, 3.4401639699935913), (17, 3.0296542048454285), (18, 3.3586398363113403), (19, 2.9370614886283875), (20, 2.913805365562439)])
loss64_hfb = np.array([(1, 52.04549503326416), (2, 25.697105884552002), (3, 16.03194546699524), (4, 11.945328712463379), (5, 9.542215585708618), (6, 7.6882710456848145), (7, 6.88703465461731), (8, 6.0323731899261475), (9, 5.538850665092468), (10, 4.822354555130005), (11, 4.705068111419678), (12, 4.14751809835434), (13, 3.784728169441223), (14, 3.5804595351219177), (15, 3.3716477751731873), (16, 3.0921711921691895), (17, 3.218214452266693), (18, 3.113940179347992), (19, 2.8746564388275146), (20, 2.7317934036254883)])

# %%
plt.plot(loss2_hfb[:,0], np.log(loss2_hfb[:,1]), label="k=2")
plt.plot(loss4_hfb[:,0], np.log(loss4_hfb[:, 1]), label="k=4")
plt.plot(loss8_hfb[:,0], np.log(loss8_hfb[:, 1]), label="k=8")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization (biased, half diagonal fixed to 1)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
plt.plot(loss16_hfb[:,0], np.log(loss16_hfb[:,1]), label="k=16")
plt.plot(loss32_hfb[:,0], np.log(loss32_hfb[:, 1]), label="k=32")
plt.plot(loss64_hfb[:,0], np.log(loss64_hfb[:, 1]), label="k=64")
plt.xlabel("Rounds")
plt.ylabel("Log(cross-entropy loss)")
plt.title("Stochastic rotation quantization (biased, half diagonal fixed to 1)")
plt.xticks(np.arange(1, 21, 2))
plt.legend()
plt.show()

# %%
avg_loss_kb = []
for loss in (loss2_kb, loss4_kb, loss8_kb, loss16_kb, loss32_kb, loss64_kb):
    avg_loss_kb.append(np.mean(loss[:, 1]))
    
avg_loss_rb = []
for loss in (loss2_rb, loss4_rb, loss8_rb, loss16_rb, loss32_rb, loss64_rb):
    avg_loss_rb.append(np.mean(loss[:, 1]))
    
avg_loss_hf = []
for loss in (loss2_hf, loss4_hf, loss8_hf, loss16_hf, loss32_hf, loss64_hf):
    avg_loss_hf.append(np.mean(loss[:, 1]))
    
avg_loss_hfb = []
for loss in (loss2_hfb, loss4_hfb, loss8_hfb, loss16_hfb, loss32_hfb, loss64_hfb):
    avg_loss_hfb.append(np.mean(loss[:, 1]))

# %%
plt.plot(2**np.arange(1, 7), (avg_loss_kb), 
         label='Stochastic k-level quantization (biased)')
plt.plot(2**np.arange(1, 7), (avg_loss_rb),
         label="Stochastic rotation quantization (biased)")
plt.plot(2**np.arange(1, 7), (avg_loss_hf), ":",
         label="Stochastic rotation quantization (half-diag-fix-1)")
plt.plot(2**np.arange(1, 7), (avg_loss_hfb), "--",
         label="Stochastic rotation quantization (biased, half-diag-fix-1)")
plt.xlabel("K")
plt.ylabel("Cross-entropy loss")
plt.title("Loss vs K on MNIST using LeNet-5 (20 rounds)")
plt.legend()
plt.show()
